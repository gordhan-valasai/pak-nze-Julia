# %% [markdown]
# # Reproduce Paper Figures\nLoads CSV outputs and regenerates figures without solving.

# %%
using CSV, DataFrames, CairoMakie, PlotlyJS

# %%
include("../post/generation_mix.jl"); include("../post/decarbonisation_trajectory.jl"); include("../post/import_dependency.jl"); include("../post/sankey_2024.jl"); include("../post/nze_emissions_decomposition.jl"); include("../post/climate_feedback_impact.jl"); include("../post/provincial_outputs.jl")

# %%
run_generation_mix(); run_decarbonisation_trajectory(); run_import_dependency(); run_sankey_2024(); run_nze_emissions_decomposition(); run_climate_feedback_impact(); run_provincial_outputs();
